# %%
df ['goal_change'] = df ['goals_after'] - df['goals_before']

df.sort_values(by="goal_change", ascending=False)

df[["player_name", "goals_before", "goals_after", "goal_change"]]
# Out:
#                    player_name  goals_before  goals_after  goal_change
# Lionel Messi                34            25           20           -5
# Cristiano Ronaldo           36            20            5          -15

# %%
print(df.head(3))

print("Rows, Columns:", df.shape)

print(df.info())

print(df.describe())

print(df.isnull().sum())
# Out:
#                    player_name age_at_transfer position preferred_foot  \
# Lionel Messi                34         Forward     Left      Argentina
# Cristiano Ronaldo           36         Forward    Right       Portugal
#
#                   nationality          from_team  to_team     from_league  \
# Lionel Messi        Barcelona                PSG  La Liga         Ligue 1
# Cristiano Ronaldo    Juventus  Manchester United  Serie A  Premier League
#
#                    to_league  from_league_rank  ...  penalty_saves_before  \
# Lionel Messi               1                 1  ...                   NaN
# Cristiano Ronaldo          1                 3  ...                   NaN
#
#                    penalty_saves_after crosses_stopped_before  \
# Lionel Messi                       NaN                    NaN
# Cristiano Ronaldo                  NaN                   78.2
#
#                   crosses_stopped_after  pass_accuracy_long_before  \
# ...

# %%
import pandas as pd 

df = pd.read_csv('data/player_transfers.csv')

df.head()
# Out:
#                    player_name age_at_transfer position preferred_foot  \
# Lionel Messi                34         Forward     Left      Argentina
# Cristiano Ronaldo           36         Forward    Right       Portugal
#
#                   nationality          from_team  to_team     from_league  \
# Lionel Messi        Barcelona                PSG  La Liga         Ligue 1
# Cristiano Ronaldo    Juventus  Manchester United  Serie A  Premier League
#
#                    to_league  from_league_rank  ...  penalty_saves_before  \
# Lionel Messi               1                 1  ...                   NaN
# Cristiano Ronaldo          1                 3  ...                   NaN
#
#                    penalty_saves_after crosses_stopped_before  \
# Lionel Messi                       NaN                    NaN
# Cristiano Ronaldo                  NaN                   78.2
#
#                   crosses_stopped_after  pass_accuracy_long_before  \
# ...
